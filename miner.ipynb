# %%
import pandas as pd
import requests

def requestData(timestamp: int) -> dict:
    """Request data from the CryptoCompare API."""
    url = "https://data-api.cryptocompare.com/news/v1/article/list?to_ts={}&limit=100".format(timestamp)
    response = requests.get(url)
    data = response.json()
    return data

starter_timestamp = 1692206525
selected_columns = ["ID", "GUID", "PUBLISHED_ON", "IMAGE_URL", "TITLE", "URL", "SOURCE_ID",
                    "BODY", "KEYWORDS", "LANG", "UPVOTES", "DOWNVOTES", "SCORE", "SENTIMENT",
                    "STATUS", "SOURCE_DATA", "CATEGORY_DATA"]

df = pd.DataFrame(columns=selected_columns)
current_month, current_year = None, None

num_iterations = 1000

for i in range(num_iterations):
    print('Current, iteration: ',i)
    data = requestData(starter_timestamp)
    new_df = pd.DataFrame(data['Data'])
    new_df = new_df[selected_columns]
    new_df['PUBLISHED_ON_DATE'] = pd.to_datetime(new_df['PUBLISHED_ON'], unit='s')

    # Check if the current month has changed
    new_month = new_df['PUBLISHED_ON_DATE'].min().month
    new_year = new_df['PUBLISHED_ON_DATE'].min().year

    if current_month is None:
        current_month, current_year = new_month, new_year

    # If the month changed, save the current df and reset it
    if current_month != new_month or current_year != new_year:
        
        df = pd.DataFrame(columns=selected_columns)  # Reset DataFrame
        current_month, current_year = new_month, new_year

    df = pd.concat([df, new_df], ignore_index=True)
    # Update the starter_timestamp
    starter_timestamp = new_df['PUBLISHED_ON'].min() - 1  # Subtracting 1 to avoid fetching the same article again
# Out:
# Current, iteration:  0
# Current, iteration:  1
# Current, iteration:  2
# Current, iteration:  3
# Current, iteration:  4
# Current, iteration:  5
# Current, iteration:  6
# Current, iteration:  7
# Current, iteration:  8
# Current, iteration:  9
# Current, iteration:  10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 23
#      21 for i in range(num_iterations):
#      22     print('Current, iteration: ',i)
# ---> 23     data = requestData(starter_timestamp)
#      24     new_df = pd.DataFrame(data['Data'])
#      25     new_df = new_df[selected_columns]
#
# Cell In[1], line 7, in requestData(timestamp)
#       5 """Request data from the CryptoCompare API."""
#       6 url = "https://data-api.cryptocompare.com/news/v1/article/list?to_ts={}&limit=100".format(timestamp)
# ----> 7 response = requests.get(url)
#       8 data = response.json()
#       9 return data
#
# File c:\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Python311\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Python311\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Python311\Lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Python311\Lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Python311\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File c:\Python311\Lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File c:\Python311\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File c:\Python311\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
df
# Out:
#            ID                                               GUID PUBLISHED_ON  \
# 0    16112834  https://u.today/xrp-gains-worldwide-adoption-a...   1692193860
# 1    16112791  https://cryptodaily.co.uk/2023/08/sei-labs-ann...   1692193800
# 2    16112761              https://www.cryptonewsz.com/?p=215964   1692193800
# 3    16112790                    https://coinpedia.org/?p=222635   1692193800
# 4    16112746                    https://coinpedia.org/?p=222667   1692193788
# ..        ...                                                ...          ...
# 995  16054986  https://cointelegraph.com/news/prime-trust-fil...   1692064549
# 996  16054599  https://www.cryptoglobe.com/latest/2023/08/xrp...   1692063360
# 997  16054224                    https://ambcrypto.com/?p=335493   1692063059
# 998  16054184                       https://nulltx.com/?p=114198   1692062983
# 999  16054138                  https://timestabloid.com/?p=19774   1692062730
#
#                                              IMAGE_URL  \
# 0    https://resources.cryptocompare.com/news/64/16...
# 1    https://resources.cryptocompare.com/news/75/16...
# 2    https://images.cryptocompare.com/news/default/...
# 3    https://images.cryptocompare.com/news/default/...
# 4    https://images.cryptocompare.com/news/default/...
# ..                                                 ...
# 995  https://resources.cryptocompare.com/news/16/16...
# 996  https://resources.cryptocompare.com/news/2/160...
# 997  https://images.cryptocompare.com/news/default/...
# 998  https://images.cryptocompare.com/news/default/...
# 999  https://resources.cryptocompare.com/news/67/de...
#
#                                                  TITLE  \
# 0    XRP Gains Worldwide Adoption as BitPay Declare...
# 1               Sei Labs Announces Mainnet Beta Launch
# 2    Compound & dYdX’s puzzle: How to keep up with ...
# 3    SBF Faces Accusations of a Major rug pull whil...
# 4    Vitalik Buterin endorses X’s “Community Notes”...
# ..                                                 ...
# 995  Crypto custodian Prime Trust files for Chapter...
# 996  $XRP Funds Attract Institutional Investors as ...
# 997  Tron’s latest achievement suggests this about ...
# 998          Top 5 Terrible Mistakes Most Traders Make
# 999  Former President Donald Trump Officially Discl...
#
#                                                    URL SOURCE_ID  \
# 0    https://u.today/xrp-gains-worldwide-adoption-a...        64
# 1    https://cryptodaily.co.uk/2023/08/sei-labs-ann...        75
# 2    https://www.cryptonewsz.com/compound-and-dydxs...        40
# 3    https://coinpedia.org/press-release/digitoads-...        53
# 4    https://coinpedia.org/crypto-live-news/vitalik...        53
# ..                                                 ...       ...
# 995  https://cointelegraph.com/news/prime-trust-fil...        16
# 996  https://www.cryptoglobe.com/latest/2023/08/xrp...         2
# 997  https://ambcrypto.com/trons-latest-achievement...        32
# 998  https://nulltx.com/top-5-terrible-mistakes-mos...        25
# 999  https://timestabloid.com/former-president-dona...        67
#
#                                                   BODY  \
# 0    Leading crypto payments service declares world...
# 1    Sei Labs has just announced the launch of its ...
# 2    VC Spectra (SPCT) has begun to demonstrate its...
# 3    The post SBF Faces Accusations of a Major rug ...
# 4    The post Vitalik Buterin endorses X’s “Communi...
# ..                                                 ...
# 995  The crypto custodian’s bankruptcy comes as it’...
# 996  Cryptocurrency investment products focusing on...
# 997  Tron adoption reached a new milestone as the t...
# 998  Cryptocurrency trading is a risky business, an...
# 999  Former President Donald Trump, who has been a ...
#
#                                               KEYWORDS LANG UPVOTES DOWNVOTES  \
# 0                                             XRP News   EN       0         0
# 1                                                        EN       0         0
# 2                                  Cryptocurrency|dYdX   EN       0         0
# 3                                        Press Release   EN       0         0
# 4                            Crypto Live News|Ethereum   EN       0         0
# ..                                                 ...  ...     ...       ...
# 995  prime trust|bankruptcy|delawre|chapter 11|prot...   EN       0         0
# 996                                   XRP|Altcoins|XRP   EN       0         0
# 997   Altcoin|News|News 1|Social|Trading View|Tron|TRX   EN       0         0
# 998            Education|bitcoin|crypto|Trader|trading   EN       0         0
# 999  Cryptocurrency|News|Donald Trump|ETH|Ethereum|...   EN       0         0
#
#     SCORE SENTIMENT  STATUS  \
# 0       0  POSITIVE  ACTIVE
# 1       0  POSITIVE  ACTIVE
# 2       0  POSITIVE  ACTIVE
# 3       0  NEGATIVE  ACTIVE
# 4       0  POSITIVE  ACTIVE
# ..    ...       ...     ...
# 995     0  NEGATIVE  ACTIVE
# 996     0  POSITIVE  ACTIVE
# 997     0   NEUTRAL  ACTIVE
# 998     0  NEGATIVE  ACTIVE
# 999     0   NEUTRAL  ACTIVE
#
#                                            SOURCE_DATA  \
# 0    {'ID': 64, 'SOURCE_KEY': 'utoday', 'NAME': 'U....
# 1    {'ID': 75, 'SOURCE_KEY': 'cryptodaily', 'NAME'...
# 2    {'ID': 40, 'SOURCE_KEY': 'cryptonewsz', 'NAME'...
# 3    {'ID': 53, 'SOURCE_KEY': 'coinpedia', 'NAME': ...
# 4    {'ID': 53, 'SOURCE_KEY': 'coinpedia', 'NAME': ...
# ..                                                 ...
# 995  {'ID': 16, 'SOURCE_KEY': 'cointelegraph', 'NAM...
# 996  {'ID': 2, 'SOURCE_KEY': 'cryptoglobe', 'NAME':...
# 997  {'ID': 32, 'SOURCE_KEY': 'ambcrypto', 'NAME': ...
# 998  {'ID': 25, 'SOURCE_KEY': 'themerkle', 'NAME': ...
# 999  {'ID': 67, 'SOURCE_KEY': 'timestabloid', 'NAME...
#
#                                          CATEGORY_DATA
# 0           [{'CATEGORY': 'XRP'}, {'CATEGORY': 'ICO'}]
# 1    [{'CATEGORY': 'BLOCKCHAIN'}, {'CATEGORY': 'EXC...
# 2     [{'CATEGORY': 'COMP'}, {'CATEGORY': 'BUSINESS'}]
# 3    [{'CATEGORY': 'MARKET'}, {'CATEGORY': 'SHIB'},...
# 4                                [{'CATEGORY': 'ETH'}]
# ..                                                 ...
# 995                            [{'CATEGORY': 'OTHER'}]
# 996  [{'CATEGORY': 'XRP'}, {'CATEGORY': 'ALTCOIN'},...
# 997  [{'CATEGORY': 'TRX'}, {'CATEGORY': 'ALTCOIN'},...
# 998  [{'CATEGORY': 'TRADING'}, {'CATEGORY': 'RESEAR...
# 999  [{'CATEGORY': 'ETH'}, {'CATEGORY': 'REGULATION'}]
#
# [1000 rows x 17 columns]

# %%
df.to_csv("selected_articles.csv", index=False)
